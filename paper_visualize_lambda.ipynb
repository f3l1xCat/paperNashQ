# %%
# In[2]:

import numpy as np
import nashpy as ns
from itertools import permutations
import lemkeHowson1 as lemkeHowson
import matrix
import rational
import multiprocessing
import matplotlib.pyplot as plt
import csv

# %%
plt.rc('font', family='Microsoft JhengHei')
res={}
with open('step6000_A=2/paper_lambda', mode='r') as f:
    reader=csv.reader(f)
    for row in reader:
        if (len(row)==0):
            continue
        row[0]=float(row[0])
        for i in range(1, len(row)):
            row[i]=row[i].replace('(','')
            row[i]=row[i].replace(')','')
            row[i]=row[i].replace(',','')
            row[i]=tuple(map(float, row[i].split(' ')))
        # print(row)
        res[row[0]]=[row[i] for i in range(1, 4)]

alpha=[]
price=[]
eposide=[i for i in res]
for i in range(1,12):
    i=i/100*2
    avg_alpha_i=(res[i][0][0]+res[i][1][0]+res[i][2][0])/3
    avg_alpha_i=avg_alpha_i/100
    alpha.append(avg_alpha_i)
    avg_price_i=(res[i][0][1]+res[i][1][1]+res[i][2][1])/3
    avg_price_i=avg_price_i/100
    price.append(avg_price_i)
    # print(avg_alpha_i, avg_price_i)

# 創建圖表
fig, ax = plt.subplots(figsize=(4, 3))

# 繪製曲線
ax.plot(eposide, alpha, label=None, color='blue', linestyle='-')
ax.plot(eposide, price, label=None, color='red', linestyle='--')

# 添加標註和箭頭
ax.annotate(r'$\alpha$(廣告數量)',
            xy=(0.04, alpha[1]), xycoords='data', # xy 是標註箭頭指向的位置。
            xytext=(0.06, 0.91), textcoords='data', # xytext 是標註文字的位置。
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3,rad=.5"))

ax.annotate(r'$p$(平台收費價格)',
            xy=(0.06, price[2]), xycoords='data',
            xytext=(0.05, 0.56), textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3,rad=.2"))

# 設置標籤和標題
ax.set_xlabel(r'廣告敏感係數 $\lambda$')
ax.set_ylabel(r'平台決策變數')
ax.set_title(r'不同$\lambda$下的平台決策變數變化圖')
ax.set_xlim(0.02, 0.2)

# 顯示圖例
# ax.legend()

# 顯示圖表
plt.show()

# %%
plt.rc('font', family='Microsoft JhengHei')
res={}
with open('step6000_A=2/paper_lambda_d', mode='r') as f:
    reader=csv.reader(f)
    for row in reader:
        if (len(row)==0):
            continue
        row[0]=float(row[0])
        for i in range(1, len(row)):
            row[i]=row[i].replace('(','')
            row[i]=row[i].replace(')','')
            row[i]=row[i].replace(',','')
            row[i]=tuple(map(float, row[i].split(' ')))
        # print(row)
        res[row[0]]=[row[i] for i in range(1, 4)]

alpha=[]
price=[]
eposide=[i for i in res]
for i in range(1,12):
    i=i/100*2
    avg_alpha_i=(res[i][0][0]+res[i][1][0]+res[i][2][0])/3
    avg_alpha_i=avg_alpha_i
    alpha.append(avg_alpha_i)
    avg_price_i=(res[i][0][1]+res[i][1][1]+res[i][2][1])/3
    avg_price_i=avg_price_i
    price.append(avg_price_i)
    # print(avg_alpha_i, avg_price_i)

# 創建圖表
fig, ax = plt.subplots(figsize=(4, 3))

# 繪製曲線
ax.plot(eposide, alpha, label=r'$N_{g}$', color='blue', linestyle='-')
ax.plot(eposide, price, label=r'$N_{c}$', color='red', linestyle='--')

# 添加標註和箭頭
ax.annotate(r'$N_{g}$(傳統搜尋引擎使用人數)',
            xy=(0.06, alpha[2]), xycoords='data', # xy 是標註箭頭指向的位置。
            xytext=(0.06, 0.51), textcoords='data', # xytext 是標註文字的位置。
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3,rad=.5"))

ax.annotate(r'$N_{c}$(AI搜尋引擎使用人數)',
            xy=(0.06, price[2]), xycoords='data',
            xytext=(0.06, 0.71), textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3,rad=.2"))

# 設置標籤和標題
ax.set_xlabel(r'網路效應係數 $\lambda$')
ax.set_ylabel(r'平台人數')
ax.set_title(r'不同$\lambda$下的平台使用人數變化圖')
ax.set_xlim(0.02, 0.2)

# 顯示圖例
# ax.legend()

# 顯示圖表
plt.show()

# %%
plt.rc('font', family='Microsoft JhengHei')
res={}
with open('step6000_A=2/paper_lambda_r', mode='r') as f:
    reader=csv.reader(f)
    for row in reader:
        if (len(row)==0):
            continue
        row[0]=float(row[0])
        for i in range(1, len(row)):
            row[i]=row[i].replace('(','')
            row[i]=row[i].replace(')','')
            row[i]=row[i].replace(',','')
            row[i]=tuple(map(float, row[i].split(' ')))
        # print(row)
        res[row[0]]=[row[i] for i in range(1, 4)]

alpha=[]
price=[]
eposide=[i for i in res]
for i in range(1,12):
    i=i/100*2
    avg_alpha_i=(res[i][0][0]+res[i][1][0]+res[i][2][0])/3
    avg_alpha_i=avg_alpha_i
    alpha.append(avg_alpha_i)
    avg_price_i=(res[i][0][1]+res[i][1][1]+res[i][2][1])/3
    avg_price_i=avg_price_i
    price.append(avg_price_i)
    # print(avg_alpha_i, avg_price_i)

# 創建圖表
fig, ax = plt.subplots(figsize=(4, 3))

# 繪製曲線
ax.plot(eposide, alpha, label=r'$\pi_{g}$', color='blue', linestyle='-')
ax.plot(eposide, price, label=r'$\pi_{c}$', color='red', linestyle='--')

# 添加標註和箭頭
ax.annotate(r'$\pi_{g}$(傳統搜尋引擎利潤)',
            xy=(0.04, alpha[1]), xycoords='data', # xy 是標註箭頭指向的位置。
            xytext=(0.05, 0.45), textcoords='data', # xytext 是標註文字的位置。
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3,rad=.5"))

ax.annotate(r'$\pi_{c}$(AI搜尋引擎利潤)',
            xy=(0.12, price[5]), xycoords='data',
            xytext=(0.1, 0.29), textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3,rad=.2"))

# 設置標籤和標題
ax.set_xlabel(r'網路效應係數 $\lambda$')
ax.set_ylabel(r'平台利潤')
ax.set_title(r'不同$\lambda$下的平台利潤變化圖')
ax.set_xlim(0.02, 0.2)

# 顯示圖例
# ax.legend()

# 顯示圖表
plt.show()

# %%
resr={}
with open('paper_diffbeta_r', mode='r') as f:
    reader=csv.reader(f)
    for row in reader:
        if (len(row)==0):
            continue
        row[0]=float(row[0])
        for i in range(1, len(row)):
            row[i]=row[i].replace('(','')
            row[i]=row[i].replace(')','')
            row[i]=row[i].replace(',','')
            row[i]=tuple(map(float, row[i].split(' ')))
        print(row)
        resr[row[0]]=[row[i] for i in range(1, 4)]
        
# dict_from_csv={int(k): v for k, v in dict_from_csv.items()}

print(resr)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 resr={}
# ----> 2 with open('paper_diffbeta_r', mode='r') as f:
#       3     reader=csv.reader(f)
#       4     for row in reader:
#
# File c:\nashQ\Thesis\nashqthesis\lib\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'paper_diffbeta_r'

# %%
piG=[]
piC=[]
eposide=[i for i in res]
for i in range(1,11):
    i=i/10
    avg_piG_i=(resr[i][0][0]+resr[i][1][0]+resr[i][2][0])/3
    avg_piG_i=avg_piG_i
    piG.append(avg_piG_i)
    avg_piC_i=(resr[i][0][1]+resr[i][1][1]+resr[i][2][1])/3
    avg_piC_i=avg_piC_i
    piC.append(avg_piC_i)
    print(avg_piG_i, avg_piC_i)

plt.figure(figsize=(12,3))
plt.xlim(0.1, 1) 
plt.ylim(0, 1)
plt.plot(eposide, piG, 'r')
plt.plot(eposide, piC, 'b')
plt.legend(labels=['傳統引擎利潤', 'AI引擎利潤'])
# Out:
# 0.5718333333333333 0.13633333333333333
# 0.5537666666666666 0.14703333333333332
# 0.2553 0.19440000000000002
# 0.29413333333333336 0.2593666666666667
# 0.23129999999999998 0.25203333333333333
# 0.24316666666666667 0.3459666666666667
# 0.30373333333333336 0.43199999999999994
# 0.23916666666666667 0.38330000000000003
# 0.19213333333333335 0.3226
# 0.13616666666666666 0.2564666666666667

# %%
import matplotlib.pyplot as plt
import numpy as np

# 假設這些數據是你所需要的
w = np.linspace(0.1, 0.63, 500)
pi_S_I = 0.1 * np.sin(2 * np.pi * w) + 0.04
pi_S_II = 0.05 * np.sin(2 * np.pi * w - np.pi / 2) + 0.06
pi_S_III = 0.03 * np.sin(2 * np.pi * w - np.pi) + 0.03

# 創建圖表
fig, ax = plt.subplots()

# 繪製曲線
ax.plot(w, pi_S_I, label=r'$\pi_{S,I}$', color='black', linestyle='-')
ax.plot(w, pi_S_II, label=r'$\pi_{S,II}$', color='black', linestyle='--')
ax.plot(w, pi_S_III, label=r'$\pi_{S,III}$', color='black', linestyle='-.')

# 添加標註和箭頭
ax.annotate(r'$\omega$',
            xy=(0.31, pi_S_II[155]), xycoords='data',
            xytext=(0.4, 0.08), textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3,rad=.5"))

ax.annotate(r'$\pi_{S,I}$',
            xy=(0.22, pi_S_I[70]), xycoords='data',
            xytext=(0.15, 0.04), textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3,rad=.2"))

ax.annotate(r'$\pi_{S,II}$',
            xy=(0.31, pi_S_II[155]), xycoords='data',
            xytext=(0.35, 0.09), textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3,rad=.2"))

ax.annotate(r'$\pi_{S,III}$',
            xy=(0.52, pi_S_III[255]), xycoords='data',
            xytext=(0.45, 0.02), textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3,rad=.2"))

# 添加垂直虛線
ax.axvline(x=0.1, color='black', linestyle=':')
ax.axvline(x=0.31, color='black', linestyle=':')
ax.axvline(x=0.52, color='black', linestyle=':')

# 設置標籤和標題
ax.set_xlabel(r'Fixed reward $w$')
ax.set_ylabel(r'Contest sponsor\'s payoff')
ax.set_title('Comparison of Contest Sponsor\'s Payoffs')

# 顯示圖例
ax.legend()

# 顯示圖表
plt.show()
